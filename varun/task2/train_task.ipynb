# %%
import pandas as pd
import numpy as np

# %% [markdown]
# reading CSV

# %%
df = pd.read_csv("/content/train.csv")
df
# Out:
#      OverallQual  YearBuilt  YearRemodAdd  TotalBsmtSF  1stFlrSF  GrLivArea  \
# 0              6     1969.0        1969.0        663.0     663.0       1352
# 1              6     1920.0        1950.0       1012.0    1012.0       1012
# 2              5     1910.0        2006.0       1022.0    1022.0       1022
# 3              5     1973.0        1973.0       1656.0    1656.0       1656
# 4              6     1978.0        1978.0        918.0     918.0       1683
# ..           ...        ...           ...          ...       ...        ...
# 821            8     2004.0        2004.0       1136.0    1136.0       2468
# 822            7     1941.0        1950.0        918.0     918.0       1646
# 823            5     1940.0        1955.0        740.0     778.0        778
# 824            4     1939.0        1950.0        732.0     772.0       1123
# 825            8     1934.0        1998.0        965.0    1940.0       3194
#
# ...

# %%
pd.set_option('display.max_columns',None)
df
# Out:
#      OverallQual  YearBuilt  YearRemodAdd  TotalBsmtSF  1stFlrSF  GrLivArea  \
# 0              6     1969.0        1969.0        663.0     663.0       1352
# 1              6     1920.0        1950.0       1012.0    1012.0       1012
# 2              5     1910.0        2006.0       1022.0    1022.0       1022
# 3              5     1973.0        1973.0       1656.0    1656.0       1656
# 4              6     1978.0        1978.0        918.0     918.0       1683
# ..           ...        ...           ...          ...       ...        ...
# 821            8     2004.0        2004.0       1136.0    1136.0       2468
# 822            7     1941.0        1950.0        918.0     918.0       1646
# 823            5     1940.0        1955.0        740.0     778.0        778
# 824            4     1939.0        1950.0        732.0     772.0       1123
# 825            8     1934.0        1998.0        965.0    1940.0       3194
#
# ...

# %% [markdown]
# Creating Column Subset

# %%
column_sub_set = df[["OverallQual","YearBuilt"]]
column_sub_set.head()
# Out:
#    OverallQual  YearBuilt
# 0            6     1969.0
# 1            6     1920.0
# 2            5     1910.0
# 3            5     1973.0
# 4            6     1978.0

# %%
column_sub_set.shape
# Out:
# (826, 2)

# %% [markdown]
# creating row subset

# %%
row_sub_set = df.loc[df['YearBuilt']>1950]
row_sub_set
# Out:
#      OverallQual  YearBuilt  YearRemodAdd  TotalBsmtSF  1stFlrSF  GrLivArea  \
# 0              6     1969.0        1969.0        663.0     663.0       1352
# 3              5     1973.0        1973.0       1656.0    1656.0       1656
# 4              6     1978.0        1978.0        918.0     918.0       1683
# 5              6     1957.0        2004.0       1477.0    1839.0       1839
# 7              7     2005.0        2005.0        600.0     520.0       1223
# ..           ...        ...           ...          ...       ...        ...
# 815            5     1961.0        1961.0       1235.0    1235.0       1235
# 816            4     1957.0        1957.0        907.0     907.0        907
# 818            5     1972.0        1972.0        882.0     882.0        882
# 819            6     1958.0        1958.0       1442.0    1442.0       1442
# 821            8     2004.0        2004.0       1136.0    1136.0       2468
#
# ...

# %% [markdown]
# creating subset using both rows and colums

# %%
sub_df= df.iloc[:500,1:6]
sub_df
# Out:
#      YearBuilt  YearRemodAdd  TotalBsmtSF  1stFlrSF  GrLivArea
# 0       1969.0        1969.0        663.0     663.0       1352
# 1       1920.0        1950.0       1012.0    1012.0       1012
# 2       1910.0        2006.0       1022.0    1022.0       1022
# 3       1973.0        1973.0       1656.0    1656.0       1656
# 4       1978.0        1978.0        918.0     918.0       1683
# ..         ...           ...          ...       ...        ...
# 495     2005.0        2005.0        547.0    1072.0       1072
# 496     1953.0        1953.0       1505.0    1505.0       1505
# 497     1921.0        2006.0        876.0     964.0        964
# 498     2005.0        2005.0        893.0     901.0       1801
# 499     1956.0        1956.0       1196.0    1196.0       1196
#
# [500 rows x 5 columns]

# %% [markdown]
#  Create a new dataframe with only the values of YearBuilt equal to 1972 and YearRemodAdd equal to 1972

# %%
new_df=df.query("YearBuilt == 1972" and "YearRemodAdd == 1972")
new_df
# Out:
#      OverallQual  YearBuilt  YearRemodAdd  TotalBsmtSF  1stFlrSF  GrLivArea  \
# 45             6     1954.0        1972.0        994.0    1216.0       1855
# 62             5     1972.0        1972.0        882.0     882.0        882
# 234            5     1972.0        1972.0        864.0     864.0        864
# 392            5     1972.0        1972.0        630.0     630.0       1302
# 532            6     1972.0        1972.0        672.0     672.0       1218
# 603            5     1972.0        1972.0        864.0     864.0        864
# 613            4     1972.0        1972.0       1138.0    1181.0       1181
# 757            6     1972.0        1972.0        483.0     483.0        987
# 801            6     1954.0        1972.0        994.0    1216.0       1855
# 818            5     1972.0        1972.0        882.0     882.0        882
#
#      FullBath  TotRmsAbvGrd  GarageCars  GarageArea  SalePrice  ExterQual_TA  \
# ...

# %% [markdown]
#  Find and remove all the null values in the dataset

# %%
df.isna().sum()
# Out:
# OverallQual         0
# YearBuilt           1
# YearRemodAdd        3
# TotalBsmtSF         1
# 1stFlrSF            2
# GrLivArea           0
# FullBath            1
# TotRmsAbvGrd        0
# GarageCars          0
# GarageArea          0
# SalePrice           0
# ExterQual_TA        2
# Foundation_PConc    0
# KitchenQual_TA      2
# dtype: int64

# %%
cleaned_df=df.loc[~df.YearBuilt.isna()]
# Out:
# OverallQual         0
# YearBuilt           0
# YearRemodAdd        3
# TotalBsmtSF         1
# 1stFlrSF            2
# GrLivArea           0
# FullBath            1
# TotRmsAbvGrd        0
# GarageCars          0
# GarageArea          0
# SalePrice           0
# ExterQual_TA        2
# Foundation_PConc    0
# KitchenQual_TA      2
# dtype: int64

# %%
cleaned_df = cleaned_df.dropna(how='any',axis=0)
cleaned_df.isna().sum()
# Out:
# OverallQual         0
# YearBuilt           0
# YearRemodAdd        0
# TotalBsmtSF         0
# 1stFlrSF            0
# GrLivArea           0
# FullBath            0
# TotRmsAbvGrd        0
# GarageCars          0
# GarageArea          0
# SalePrice           0
# ExterQual_TA        0
# Foundation_PConc    0
# KitchenQual_TA      0
# dtype: int64

# %% [markdown]
# Show a scatterplot between YearBulit and SalePrice

# %%
df.plot(kind="scatter",x='YearBuilt',y="SalePrice")
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='YearBuilt', ylabel='SalePrice'>
