# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# ## Read the dataset

# %%
df = pd.read_csv('/content/train.csv')

# %%
df.head()
# Out:
#    OverallQual  YearBuilt  YearRemodAdd  TotalBsmtSF  1stFlrSF  GrLivArea  \
# 0            6     1969.0        1969.0        663.0     663.0       1352
# 1            6     1920.0        1950.0       1012.0    1012.0       1012
# 2            5     1910.0        2006.0       1022.0    1022.0       1022
# 3            5     1973.0        1973.0       1656.0    1656.0       1656
# 4            6     1978.0        1978.0        918.0     918.0       1683
#
#    FullBath  TotRmsAbvGrd  GarageCars  GarageArea  SalePrice  ExterQual_TA  \
# 0       1.0             7           1         299     158000           1.0
# 1       1.0             6           1         308     118400           1.0
# 2       1.0             4           1         280      85000           1.0
# 3       2.0             8           2         506     135000           1.0
# 4       2.0             7           2         440     172500           1.0
#
#    Foundation_PConc  KitchenQual_TA
# ...

# %%
df.shape
# Out:
# (826, 14)

# %% [markdown]
# ## Subset the dataframe

# %%
df.columns
# Out:
# Index(['OverallQual', 'YearBuilt', 'YearRemodAdd', 'TotalBsmtSF', '1stFlrSF',
#        'GrLivArea', 'FullBath', 'TotRmsAbvGrd', 'GarageCars', 'GarageArea',
#        'SalePrice', 'ExterQual_TA', 'Foundation_PConc', 'KitchenQual_TA'],
#       dtype='object')

# %%
# Subsetting the dataset by columns
sub1 = df[['OverallQual', 'YearBuilt', 'YearRemodAdd']]

# %%
sub1.head()
# Out:
#    OverallQual  YearBuilt  YearRemodAdd
# 0            6     1969.0        1969.0
# 1            6     1920.0        1950.0
# 2            5     1910.0        2006.0
# 3            5     1973.0        1973.0
# 4            6     1978.0        1978.0

# %%
sub1.shape
# Out:
# (826, 3)

# %%
sub2 = df.iloc[:,2:7]

# %%
sub2.head()
# Out:
#    YearRemodAdd  TotalBsmtSF  1stFlrSF  GrLivArea  FullBath
# 0        1969.0        663.0     663.0       1352       1.0
# 1        1950.0       1012.0    1012.0       1012       1.0
# 2        2006.0       1022.0    1022.0       1022       1.0
# 3        1973.0       1656.0    1656.0       1656       2.0
# 4        1978.0        918.0     918.0       1683       2.0

# %%
sub2.shape
# Out:
# (826, 5)

# %%
# subsetting dataset by rows
sub3 = df[df['YearBuilt']>1950]

# %%
sub3.head()
# Out:
#    OverallQual  YearBuilt  YearRemodAdd  TotalBsmtSF  1stFlrSF  GrLivArea  \
# 0            6     1969.0        1969.0        663.0     663.0       1352
# 3            5     1973.0        1973.0       1656.0    1656.0       1656
# 4            6     1978.0        1978.0        918.0     918.0       1683
# 5            6     1957.0        2004.0       1477.0    1839.0       1839
# 7            7     2005.0        2005.0        600.0     520.0       1223
#
#    FullBath  TotRmsAbvGrd  GarageCars  GarageArea  SalePrice  ExterQual_TA  \
# 0       1.0             7           1         299     158000           1.0
# 3       2.0             8           2         506     135000           1.0
# 4       2.0             7           2         440     172500           1.0
# 5       2.0             7           2         416     257500           1.0
# 7       2.0             4           2         480     147400           0.0
#
#    Foundation_PConc  KitchenQual_TA
# ...

# %%
sub3.shape
# Out:
# (626, 14)

# %%
sub4 = df.iloc[:6,:]

# %%
sub4
# Out:
#    OverallQual  YearBuilt  YearRemodAdd  TotalBsmtSF  1stFlrSF  GrLivArea  \
# 0            6     1969.0        1969.0        663.0     663.0       1352
# 1            6     1920.0        1950.0       1012.0    1012.0       1012
# 2            5     1910.0        2006.0       1022.0    1022.0       1022
# 3            5     1973.0        1973.0       1656.0    1656.0       1656
# 4            6     1978.0        1978.0        918.0     918.0       1683
# 5            6     1957.0        2004.0       1477.0    1839.0       1839
#
#    FullBath  TotRmsAbvGrd  GarageCars  GarageArea  SalePrice  ExterQual_TA  \
# 0       1.0             7           1         299     158000           1.0
# 1       1.0             6           1         308     118400           1.0
# 2       1.0             4           1         280      85000           1.0
# 3       2.0             8           2         506     135000           1.0
# ...

# %%
sub4.shape
# Out:
# (6, 14)

# %%
# subsetting the dataset by rows and columns
sub5 = df.iloc[2:9,5:8]

# %%
sub5
# Out:
#    GrLivArea  FullBath  TotRmsAbvGrd
# 2       1022       1.0             4
# 3       1656       2.0             8
# 4       1683       2.0             7
# 5       1839       2.0             7
# 6       1647       1.0             6
# 7       1223       2.0             4
# 8       1920       3.0             8

# %%
sub5.shape
# Out:
# (7, 3)

# %% [markdown]
# ## New DataFrame

# %%
df2 = df.query('YearBuilt == 1972 and YearRemodAdd == 1972')

# %%
df2
# Out:
#      OverallQual  YearBuilt  YearRemodAdd  TotalBsmtSF  1stFlrSF  GrLivArea  \
# 62             5     1972.0        1972.0        882.0     882.0        882
# 234            5     1972.0        1972.0        864.0     864.0        864
# 392            5     1972.0        1972.0        630.0     630.0       1302
# 532            6     1972.0        1972.0        672.0     672.0       1218
# 603            5     1972.0        1972.0        864.0     864.0        864
# 613            4     1972.0        1972.0       1138.0    1181.0       1181
# 757            6     1972.0        1972.0        483.0     483.0        987
# 818            5     1972.0        1972.0        882.0     882.0        882
#
#      FullBath  TotRmsAbvGrd  GarageCars  GarageArea  SalePrice  ExterQual_TA  \
# 62        1.0             5           2         461     112500           1.0
# 234       1.0             5           1         352     127000           1.0
# ...

# %%
df2.shape
# Out:
# (8, 14)

# %% [markdown]
# ## Null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10 entries, 45 to 818
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   OverallQual       10 non-null     int64
#  1   YearBuilt         10 non-null     float64
#  2   YearRemodAdd      10 non-null     float64
#  3   TotalBsmtSF       10 non-null     float64
#  4   1stFlrSF          10 non-null     float64
#  5   GrLivArea         10 non-null     int64
#  6   FullBath          10 non-null     float64
#  7   TotRmsAbvGrd      10 non-null     int64
#  8   GarageCars        10 non-null     int64
#  9   GarageArea        10 non-null     int64
#  10  SalePrice         10 non-null     int64
#  11  ExterQual_TA      10 non-null     float64
#  12  Foundation_PConc  10 non-null     int64
#  13  KitchenQual_TA    10 non-null     float64
# dtypes: float64(7), int64(7)
# memory usage: 1.2 KB

# %%
df.isnull()
# Out:
#      OverallQual  YearBuilt  YearRemodAdd  TotalBsmtSF  1stFlrSF  GrLivArea  \
# 45         False      False         False        False     False      False
# 62         False      False         False        False     False      False
# 234        False      False         False        False     False      False
# 392        False      False         False        False     False      False
# 532        False      False         False        False     False      False
# 603        False      False         False        False     False      False
# 613        False      False         False        False     False      False
# 757        False      False         False        False     False      False
# 801        False      False         False        False     False      False
# 818        False      False         False        False     False      False
#
#      FullBath  TotRmsAbvGrd  GarageCars  GarageArea  SalePrice  ExterQual_TA  \
# ...

# %%
df.isnull().sum()
# Out:
# OverallQual         0
# YearBuilt           0
# YearRemodAdd        0
# TotalBsmtSF         0
# 1stFlrSF            0
# GrLivArea           0
# FullBath            0
# TotRmsAbvGrd        0
# GarageCars          0
# GarageArea          0
# SalePrice           0
# ExterQual_TA        0
# Foundation_PConc    0
# KitchenQual_TA      0
# dtype: int64

# %%
df.isna().sum()
# Out:
# OverallQual         0
# YearBuilt           0
# YearRemodAdd        0
# TotalBsmtSF         0
# 1stFlrSF            0
# GrLivArea           0
# FullBath            0
# TotRmsAbvGrd        0
# GarageCars          0
# GarageArea          0
# SalePrice           0
# ExterQual_TA        0
# Foundation_PConc    0
# KitchenQual_TA      0
# dtype: int64

# %%
df.isna().sum().sum()
# Hence no null values
# Out:
# 0

# %% [markdown]
# ## Plotting

# %%
df.plot(kind="scatter",y="SalePrice",x="YearBuilt")
# Out:
# <Axes: xlabel='YearBuilt', ylabel='SalePrice'>
