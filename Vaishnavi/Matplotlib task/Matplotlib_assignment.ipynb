# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Scatterplot

# %%
iris = pd.read_csv('/content/Iris.csv')

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
x = iris["SepalLengthCm"]
y = iris["PetalWidthCm"]
colors = iris["PetalLengthCm"]
size = iris["SepalWidthCm"]

# %%
plt.title("Iris Dataset Scatterplot")
plt.xlabel("SepalLength")
plt.ylabel("PetalWidth")
plt.scatter(x,y,c = colors,s=size)

# %% [markdown]
# ## Barplot

# %%
Calories = np.random.randint(low=100,high=700,size=10)
time_in_min = np.random.random(10)
x_axis = np.arange(len(time_in_min))

# %%
plt.title("Calories burnt after workout session")
plt.xlabel("Time in hr")
plt.ylabel("Calories")
plt.bar(x_axis,Calories,color="r")
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# ## Lineplot

# %%
heart_rate_permin = np.random.randint(low=68,high=101,size=3)

# %%
plt.plot(heart_rate_permin,linestyle="dotted",c='green')
