# %% [markdown]
# <a href="https://colab.research.google.com/github/PranitaAbbireddy/pre-bootcamp/blob/main/task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/train.csv")
df
# Out:
#      OverallQual  YearBuilt  YearRemodAdd  TotalBsmtSF  1stFlrSF  GrLivArea  \
# 0              6     1969.0        1969.0        663.0     663.0       1352
# 1              6     1920.0        1950.0       1012.0    1012.0       1012
# 2              5     1910.0        2006.0       1022.0    1022.0       1022
# 3              5     1973.0        1973.0       1656.0    1656.0       1656
# 4              6     1978.0        1978.0        918.0     918.0       1683
# ..           ...        ...           ...          ...       ...        ...
# 821            8     2004.0        2004.0       1136.0    1136.0       2468
# 822            7     1941.0        1950.0        918.0     918.0       1646
# 823            5     1940.0        1955.0        740.0     778.0        778
# 824            4     1939.0        1950.0        732.0     772.0       1123
# 825            8     1934.0        1998.0        965.0    1940.0       3194
#
# ...

# %%
sub_df=df[["OverallQual","YearBuilt"]]
sub_df.head()
# Out:
#    OverallQual  YearBuilt
# 0            6     1969.0
# 1            6     1920.0
# 2            5     1910.0
# 3            5     1973.0
# 4            6     1978.0

# %%
sub_df=df[df["YearBuilt"]>2004]
sub_df
# Out:
#      OverallQual  YearBuilt  YearRemodAdd  TotalBsmtSF  1stFlrSF  GrLivArea  \
# 7              7     2005.0        2005.0        600.0     520.0       1223
# 15             9     2005.0        2006.0       1175.0    1182.0       2324
# 17             8     2006.0        2006.0       1088.0    1088.0       1959
# 19             7     2006.0        2006.0        728.0     728.0       1456
# 23             7     2005.0        2006.0       1373.0    1555.0       1555
# ..           ...        ...           ...          ...       ...        ...
# 775            7     2006.0        2006.0        728.0     728.0       1456
# 779            7     2005.0        2006.0       1373.0    1555.0       1555
# 790            7     2007.0        2007.0        728.0     728.0       1456
# 794           10     2007.0        2008.0       2078.0    2084.0       2084
# 812           10     2009.0        2009.0       2006.0    2020.0       2020
#
# ...

# %%
sub_df=df.iloc[:10,:4]
sub_df
# Out:
#    OverallQual  YearBuilt  YearRemodAdd  TotalBsmtSF
# 0            6     1969.0        1969.0        663.0
# 1            6     1920.0        1950.0       1012.0
# 2            5     1910.0        2006.0       1022.0
# 3            5     1973.0        1973.0       1656.0
# 4            6     1978.0        1978.0        918.0
# 5            6     1957.0        2004.0       1477.0
# 6            6     1915.0        1950.0        806.0
# 7            7     2005.0        2005.0        600.0
# 8            7     1968.0        1992.0        570.0
# 9            5     1963.0        1963.0       1120.0

# %%
df_new=df[(df["YearBuilt"]==1972)&(df["YearRemodAdd"]==1972)]
df_new
# Out:
#      OverallQual  YearBuilt  YearRemodAdd  TotalBsmtSF  1stFlrSF  GrLivArea  \
# 62             5     1972.0        1972.0        882.0     882.0        882
# 234            5     1972.0        1972.0        864.0     864.0        864
# 392            5     1972.0        1972.0        630.0     630.0       1302
# 532            6     1972.0        1972.0        672.0     672.0       1218
# 603            5     1972.0        1972.0        864.0     864.0        864
# 613            4     1972.0        1972.0       1138.0    1181.0       1181
# 757            6     1972.0        1972.0        483.0     483.0        987
# 818            5     1972.0        1972.0        882.0     882.0        882
#
#      FullBath  TotRmsAbvGrd  GarageCars  GarageArea  SalePrice  ExterQual_TA  \
# 62        1.0             5           2         461     112500           1.0
# 234       1.0             5           1         352     127000           1.0
# ...

# %%
df.isna().sum()
# Out:
# OverallQual         0
# YearBuilt           1
# YearRemodAdd        3
# TotalBsmtSF         1
# 1stFlrSF            2
# GrLivArea           0
# FullBath            1
# TotRmsAbvGrd        0
# GarageCars          0
# GarageArea          0
# SalePrice           0
# ExterQual_TA        2
# Foundation_PConc    0
# KitchenQual_TA      2
# dtype: int64

# %%
cleaned_df=cleaned_df.loc[~df.YearBuilt.isna()]

# %%
cleaned_df=cleaned_df.loc[~df.YearRemodAdd.isna()]

# %%
cleaned_df=cleaned_df.loc[~df.TotalBsmtSF.isna()]

# %%
cleaned_df=cleaned_df.loc[~df.FullBath.isna()]

# %%
cleaned_df=cleaned_df.loc[~df.ExterQual_TA.isna()]

# %%
cleaned_df=cleaned_df.loc[~df.KitchenQual_TA.isna()]

# %%
df = df.rename(columns={'1stFlrSF': 'FlrSF'})

# %%
cleaned_df=cleaned_df.loc[~df.FlrSF.isna()]

# %%
cleaned_df.isna().sum()
# Out:
# OverallQual         0
# YearBuilt           0
# YearRemodAdd        0
# TotalBsmtSF         0
# FlrSF               0
# GrLivArea           0
# FullBath            0
# TotRmsAbvGrd        0
# GarageCars          0
# GarageArea          0
# SalePrice           0
# ExterQual_TA        0
# Foundation_PConc    0
# KitchenQual_TA      0
# dtype: int64

# %%
df.plot(kind="scatter",y="YearBuilt", x = "SalePrice")
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='SalePrice', ylabel='YearBuilt'>
