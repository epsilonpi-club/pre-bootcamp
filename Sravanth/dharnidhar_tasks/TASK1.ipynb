# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
 x = np.linspace(0,10,10000)
y= (math.e - x)/(10 * np.sin(x))
plt.plot(x,y)
# Out:
# C:\Users\sravanth\AppData\Local\Temp\ipykernel_9492\1019305904.py:2: RuntimeWarning: divide by zero encountered in divide
#   y= (math.e - x)/(10 * np.sin(x))

# %%
x1= np.array([4,7])
y1 = (math.e - x1)/(10 * np.sin(x1))
plt.plot(x1,y1)

# %%
np.mean(x1)
np.std(x1)
# Out:
# 1.5

# %%
ym = np.percentile(x1, 80)
ym
# Out:
# 6.4

# %%
#a=np.diff(y)/diff(x)
#plt.plot(x,a)
